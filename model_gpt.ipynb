# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
results_all   = pd.read_csv("match_results/results.csv", parse_dates=["date"])
results_clean = pd.read_csv("match_results/results_clean.csv", parse_dates=["date"])
team_universe = pd.read_csv("reference_data/team_universe.csv", header=None)[0].to_list()

def get_results(team, results=results_clean):
    return results.query(f"home_team == '{team}' or away_team == '{team}'")

# %%
import math
from dataclasses import dataclass
from typing import Dict, List, Optional, Tuple

import numpy as np
import pandas as pd


class Model:
    def __init__(self):
        self._is_fit = False

    def fit(self, results):
        pass

    def score(self):
        if not self._is_fit:
            raise Exception("Cannot score un-fit model")


@dataclass
class TeamState:
    """Gaussian belief over (attack, defence), tracked at last_update time."""
    m: np.ndarray              # shape (2,) -> [a, d]
    sigma2: float              # scalar variance scale (>=0), covariance = sigma2 * [[1,q0],[q0,1]]
    last_update: pd.Timestamp


class FastDynamicBivarPoissonAD(Model):
    """
    Fast online attack/defence model for international football with:
      - continuous-time forgetting via scalar uncertainty growth: sigma2 <- sigma2 + q * Δt
        and per-team covariance constrained to sigma2 * [[1,q0],[q0,1]]
      - bivariate Poisson scoreline model with shared intensity:
            nu = rho * min(mH, mA)
      - per-match MAP update using analytic gradient + Gauss-Newton Hessian approx
        with full (block-diagonal) prior precision.

    Outputs:
      - self.results_: copy of input df with prediction + loss columns
      - self.params_history_: long-form history of per-team parameters at each match date
    """

    def __init__(
        self,
        # Score model hyperparams (dimensionless on log intensity scale)
        mu: float = math.log(1.25),       # baseline log goals per team
        home_adv: float = 0.12,           # added if not neutral
        rho: float = 0.15,                # correlation scale in [0,1)
        # Attack/defence uncertainty correlation hyperparam (NOT the same as score-model rho)
        q0: float = 0.3,                  # Corr(a,d) within team belief; must be in (-1,1)
        # Time forgetting hyperparams (sigma2 per day; shared for all teams)
        drift_var_per_day: float = 2e-4,
        # Initial prior uncertainty scale for unseen teams (sigma2)
        init_var: float = 0.5,
        # Prediction truncation for W/D/L probs from score matrix
        max_goals: int = 10,
        # Numerical / optimisation knobs
        eps: float = 1e-15,
        map_steps: int = 3,               # typically 2–4 is enough
        hess_damping: float = 1e-6,       # stabilises 4x4 solve
    ):
        super().__init__()
        if not (0.0 <= rho < 1.0):
            raise ValueError("rho must be in [0, 1).")
        if not (-1.0 < q0 < 1.0):
            raise ValueError("q0 must be in (-1, 1).")
        if drift_var_per_day < 0:
            raise ValueError("drift_var_per_day must be >= 0.")
        if init_var <= 0:
            raise ValueError("init_var must be > 0.")
        if max_goals < 0:
            raise ValueError("max_goals must be >= 0.")

        self.mu = float(mu)
        self.home_adv = float(home_adv)
        self.rho = float(rho)
        self.q0 = float(q0)
        self.drift_var_per_day = float(drift_var_per_day)
        self.init_var = float(init_var)
        self.max_goals = int(max_goals)
        self.eps = float(eps)
        self.map_steps = int(map_steps)
        self.hess_damping = float(hess_damping)

        # Precompute R and R^{-1} for projection / prior blocks
        self._R = np.array([[1.0, self.q0], [self.q0, 1.0]], dtype=float)
        denom = 1.0 - self.q0 * self.q0
        self._Rinv = (1.0 / denom) * np.array([[1.0, -self.q0], [-self.q0, 1.0]], dtype=float)

        # Fit artifacts required by user
        self.results_: Optional[pd.DataFrame] = None
        self.params_history_: Optional[pd.DataFrame] = None

        # Internal state
        self._teams: Dict[str, TeamState] = {}

    # -------------------------
    # Utilities
    # -------------------------

    @staticmethod
    def _outcome_from_score(hg: int, ag: int) -> str:
        if hg > ag:
            return "H"
        if hg < ag:
            return "A"
        return "D"

    def _get_or_init_team(self, team: str, t: pd.Timestamp) -> TeamState:
        st = self._teams.get(team)
        if st is not None:
            return st
        st = TeamState(
            m=np.array([0.0, 0.0], dtype=float),
            sigma2=float(self.init_var),
            last_update=t,
        )
        self._teams[team] = st
        return st

    def _propagate_to_time(self, st: TeamState, t: pd.Timestamp) -> None:
        dt_days = float(max((t - st.last_update) / np.timedelta64(1, "D"), 0.0))
        if dt_days > 0.0 and self.drift_var_per_day > 0.0:
            st.sigma2 = float(st.sigma2 + self.drift_var_per_day * dt_days)
            st.last_update = t
        else:
            st.last_update = t

    def _team_cov(self, sigma2: float) -> np.ndarray:
        sigma2 = float(max(sigma2, 1e-12))
        return sigma2 * self._R

    def _team_prec(self, sigma2: float) -> np.ndarray:
        sigma2 = float(max(sigma2, 1e-12))
        return (1.0 / sigma2) * self._Rinv

    # -------------------------
    # Score model
    # -------------------------

    def _means_from_z(self, z: np.ndarray, neutral: bool) -> Tuple[float, float]:
        # z = [a_h, d_h, a_a, d_a]
        a_h, d_h, a_a, d_a = map(float, z)
        h = 0.0 if neutral else self.home_adv
        mH = math.exp(self.mu + h + a_h - d_a)
        mA = math.exp(self.mu + a_a - d_h)
        return mH, mA

    def _nu_lams(self, mH: float, mA: float) -> Tuple[float, float, float, bool]:
        """
        nu = rho * min(mH, mA)
        lam_h = mH - nu
        lam_a = mA - nu
        Returns (nu, lam_h, lam_a, home_is_min)
        """
        if mH <= mA:
            nu = self.rho * mH
            lam_h = mH - nu
            lam_a = mA - nu
            return nu, lam_h, lam_a, True
        else:
            nu = self.rho * mA
            lam_h = mH - nu
            lam_a = mA - nu
            return nu, lam_h, lam_a, False

    @staticmethod
    def _poisson_pmf_up_to(lam: float, G: int) -> np.ndarray:
        pmf = np.zeros(G + 1, dtype=float)
        if lam < 0:
            return pmf
        pmf[0] = math.exp(-lam)
        if G == 0:
            return pmf
        for k in range(1, G + 1):
            pmf[k] = pmf[k - 1] * lam / k
        return pmf

    def _bivar_prob_matrix(self, lam_h: float, lam_a: float, nu: float, G: int) -> np.ndarray:
        pu = self._poisson_pmf_up_to(nu, G)
        pv = self._poisson_pmf_up_to(lam_h, G)
        pw = self._poisson_pmf_up_to(lam_a, G)

        P = np.zeros((G + 1, G + 1), dtype=float)
        for k in range(0, G + 1):
            pk = pu[k]
            if pk == 0.0:
                continue
            vv = pv[: G + 1 - k]
            ww = pw[: G + 1 - k]
            P[k:, k:] += pk * np.outer(vv, ww)
        return P

    def _score_logpmf(self, x: int, y: int, lam_h: float, lam_a: float, nu: float) -> float:
        if lam_h < 0 or lam_a < 0 or nu < 0:
            return -np.inf

        kmax = min(x, y)
        if nu == 0.0:
            return (
                -(lam_h + lam_a)
                + (x * math.log(lam_h) if x > 0 else 0.0)
                + (y * math.log(lam_a) if y > 0 else 0.0)
                - math.lgamma(x + 1.0)
                - math.lgamma(y + 1.0)
            )

        log_terms = np.empty(kmax + 1, dtype=float)
        log_lh = -np.inf if lam_h == 0.0 else math.log(lam_h)
        log_la = -np.inf if lam_a == 0.0 else math.log(lam_a)
        log_nu = math.log(nu)

        for k in range(kmax + 1):
            if x - k < 0 or y - k < 0:
                log_terms[k] = -np.inf
                continue

            lt = 0.0
            if x - k > 0:
                if lam_h == 0.0:
                    log_terms[k] = -np.inf
                    continue
                lt += (x - k) * log_lh

            if y - k > 0:
                if lam_a == 0.0:
                    log_terms[k] = -np.inf
                    continue
                lt += (y - k) * log_la

            if k > 0:
                lt += k * log_nu

            lt -= math.lgamma((x - k) + 1.0)
            lt -= math.lgamma((y - k) + 1.0)
            lt -= math.lgamma(k + 1.0)
            log_terms[k] = lt

        m = float(np.max(log_terms))
        if not np.isfinite(m):
            return -np.inf
        lse = m + float(np.log(np.sum(np.exp(log_terms - m))))
        return -(lam_h + lam_a + nu) + lse

    def _expected_k(self, x: int, y: int, lam_h: float, lam_a: float, nu: float) -> float:
        kmax = min(x, y)
        if kmax == 0 or nu == 0.0:
            return 0.0

        log_lh = -np.inf if lam_h == 0.0 else math.log(lam_h)
        log_la = -np.inf if lam_a == 0.0 else math.log(lam_a)
        log_nu = math.log(nu)

        log_terms = np.empty(kmax + 1, dtype=float)
        for k in range(kmax + 1):
            if x - k < 0 or y - k < 0:
                log_terms[k] = -np.inf
                continue
            lt = 0.0
            if x - k > 0:
                if lam_h == 0.0:
                    log_terms[k] = -np.inf
                    continue
                lt += (x - k) * log_lh
            if y - k > 0:
                if lam_a == 0.0:
                    log_terms[k] = -np.inf
                    continue
                lt += (y - k) * log_la
            if k > 0:
                lt += k * log_nu
            lt -= math.lgamma((x - k) + 1.0)
            lt -= math.lgamma((y - k) + 1.0)
            lt -= math.lgamma(k + 1.0)
            log_terms[k] = lt

        m = float(np.max(log_terms))
        if not np.isfinite(m):
            return 0.0

        w = np.exp(log_terms - m)
        s = float(np.sum(w))
        if s <= 0.0:
            return 0.0
        w /= s
        ks = np.arange(kmax + 1, dtype=float)
        return float(np.sum(ks * w))

    # -------------------------
    # Fast MAP update (analytic grad + Gauss-Newton Hessian)
    # -------------------------

    def _map_update(
        self,
        prior_m: np.ndarray,       # shape (4,)
        prior_prec: np.ndarray,    # shape (4,4) full precision
        x: int,
        y: int,
        neutral: bool,
    ) -> Tuple[np.ndarray, np.ndarray]:
        """
        Return (post_mean_z, post_cov_z) for z=[a_h,d_h,a_a,d_a].
        Uses a few damped Newton steps with:
          grad = prior_prec @ (z-prior_m) - grad_loglik
          Hess ≈ prior_prec + sum_c w_c * (dlam_c/dz)(dlam_c/dz)^T  (Gauss-Newton)
        """
        z = prior_m.copy()

        for _ in range(self.map_steps):
            mH, mA = self._means_from_z(z, neutral)
            nu, lam_h, lam_a, home_is_min = self._nu_lams(mH, mA)

            lam_h = max(lam_h, 1e-12)
            lam_a = max(lam_a, 1e-12)
            nu_eps = max(nu, 1e-12)

            ek = self._expected_k(x, y, lam_h, lam_a, nu)
            ex = x - ek
            ey = y - ek

            dL_dlam_h = ex / lam_h - 1.0
            dL_dlam_a = ey / lam_a - 1.0
            dL_dnu = ek / nu_eps - 1.0

            dmH_dz = mH * np.array([1.0, 0.0, 0.0, -1.0], dtype=float)
            dmA_dz = mA * np.array([0.0, -1.0, 1.0, 0.0], dtype=float)

            if home_is_min:
                dnu_dmH, dnu_dmA = self.rho, 0.0
                dlh_dmH, dlh_dmA = 1.0 - self.rho, 0.0
                dla_dmH, dla_dmA = -self.rho, 1.0
            else:
                dnu_dmH, dnu_dmA = 0.0, self.rho
                dlh_dmH, dlh_dmA = 1.0, -self.rho
                dla_dmH, dla_dmA = 0.0, 1.0 - self.rho

            dnu_dz = dnu_dmH * dmH_dz + dnu_dmA * dmA_dz
            dlh_dz = dlh_dmH * dmH_dz + dlh_dmA * dmA_dz
            dla_dz = dla_dmH * dmH_dz + dla_dmA * dmA_dz

            grad_loglik = dL_dlam_h * dlh_dz + dL_dlam_a * dla_dz + dL_dnu * dnu_dz

            grad = prior_prec @ (z - prior_m) - grad_loglik

            w_lh = max(ex, 0.0) / (lam_h * lam_h)
            w_la = max(ey, 0.0) / (lam_a * lam_a)
            w_nu = max(ek, 0.0) / (nu_eps * nu_eps)

            H = prior_prec.copy()
            H += w_lh * np.outer(dlh_dz, dlh_dz)
            H += w_la * np.outer(dla_dz, dla_dz)
            H += w_nu * np.outer(dnu_dz, dnu_dz)
            H += self.hess_damping * np.eye(4)

            try:
                step = np.linalg.solve(H, grad)
            except np.linalg.LinAlgError:
                step = np.linalg.pinv(H) @ grad

            z_new = z - step
            if float(np.linalg.norm(z_new - z)) < 1e-6:
                z = z_new
                break
            z = z_new

        # Approx posterior covariance from inverse Hessian at final iterate
        mH, mA = self._means_from_z(z, neutral)
        nu, lam_h, lam_a, home_is_min = self._nu_lams(mH, mA)

        lam_h = max(lam_h, 1e-12)
        lam_a = max(lam_a, 1e-12)
        nu_eps = max(nu, 1e-12)

        ek = self._expected_k(x, y, lam_h, lam_a, nu)
        ex = x - ek
        ey = y - ek

        dmH_dz = mH * np.array([1.0, 0.0, 0.0, -1.0], dtype=float)
        dmA_dz = mA * np.array([0.0, -1.0, 1.0, 0.0], dtype=float)

        if home_is_min:
            dnu_dmH, dnu_dmA = self.rho, 0.0
            dlh_dmH, dlh_dmA = 1.0 - self.rho, 0.0
            dla_dmH, dla_dmA = -self.rho, 1.0
        else:
            dnu_dmH, dnu_dmA = 0.0, self.rho
            dlh_dmH, dlh_dmA = 1.0, -self.rho
            dla_dmH, dla_dmA = 0.0, 1.0 - self.rho

        dnu_dz = dnu_dmH * dmH_dz + dnu_dmA * dmA_dz
        dlh_dz = dlh_dmH * dmH_dz + dlh_dmA * dmA_dz
        dla_dz = dla_dmH * dmH_dz + dla_dmA * dmA_dz

        w_lh = max(ex, 0.0) / (lam_h * lam_h)
        w_la = max(ey, 0.0) / (lam_a * lam_a)
        w_nu = max(ek, 0.0) / (nu_eps * nu_eps)

        H = prior_prec.copy()
        H += w_lh * np.outer(dlh_dz, dlh_dz)
        H += w_la * np.outer(dla_dz, dla_dz)
        H += w_nu * np.outer(dnu_dz, dnu_dz)
        H += self.hess_damping * np.eye(4)

        try:
            cov = np.linalg.inv(H)
        except np.linalg.LinAlgError:
            cov = np.linalg.pinv(H)

        return z, cov

    def _project_sigma2(self, P2: np.ndarray) -> float:
        """
        Given a 2x2 covariance block P2, project to sigma2*R by:
          sigma2 = 0.5 * tr(R^{-1} P2)
        """
        s2 = 0.5 * float(np.trace(self._Rinv @ P2))
        return float(max(s2, 1e-12))

    # -------------------------
    # Fit
    # -------------------------

    def fit(self, results: pd.DataFrame) -> None:
        if not isinstance(results, pd.DataFrame):
            raise TypeError("results must be a pandas DataFrame")

        df = results.copy()
        df = df.sort_values("date").reset_index(drop=True)

        needed = {"date", "home_team", "away_team", "home_score", "away_score", "neutral"}
        missing = needed - set(df.columns)
        if missing:
            raise ValueError(f"results is missing required columns: {sorted(missing)}")

        for col in [
            "pr_home_win", "pr_draw", "pr_away_win",
            "pr_outcome", "pr_score",
            "loss_outcome", "loss_score",
        ]:
            df[col] = np.nan

        params_rows: List[dict] = []
        G = self.max_goals
        eps = self.eps

        for idx, row in df.iterrows():
            t = pd.Timestamp(row["date"])
            home = str(row["home_team"])
            away = str(row["away_team"])
            x = int(row["home_score"])
            y = int(row["away_score"])
            neutral = bool(row["neutral"])

            # init + propagate
            st_h = self._get_or_init_team(home, t)
            st_a = self._get_or_init_team(away, t)
            self._propagate_to_time(st_h, t)
            self._propagate_to_time(st_a, t)

            # Prior mean for z=[a_h,d_h,a_a,d_a]
            prior_m = np.array([st_h.m[0], st_h.m[1], st_a.m[0], st_a.m[1]], dtype=float)

            # Prior precision (block diagonal with 2x2 blocks)
            Prec_h = self._team_prec(st_h.sigma2)
            Prec_a = self._team_prec(st_a.sigma2)
            prior_prec = np.zeros((4, 4), dtype=float)
            prior_prec[:2, :2] = Prec_h
            prior_prec[2:, 2:] = Prec_a

            # Predict via fast matrix construction at prior mean (unchanged plug-in)
            mH, mA = self._means_from_z(prior_m, neutral)
            nu, lam_h, lam_a, _ = self._nu_lams(mH, mA)

            Pxy = self._bivar_prob_matrix(lam_h, lam_a, nu, G)

            pr_h = float(np.sum(Pxy[np.tril_indices(G + 1, k=-1)]))
            pr_d = float(np.sum(np.diag(Pxy)))
            pr_a = float(np.sum(Pxy[np.triu_indices(G + 1, k=1)]))

            s_out = pr_h + pr_d + pr_a
            if s_out > 0.0:
                pr_h /= s_out
                pr_d /= s_out
                pr_a /= s_out

            if x <= G and y <= G:
                pr_score = float(np.clip(Pxy[x, y], eps, 1.0))
            else:
                lp = self._score_logpmf(x, y, lam_h, lam_a, nu)
                pr_score = float(np.clip(math.exp(lp) if np.isfinite(lp) else 0.0, eps, 1.0))

            outcome = self._outcome_from_score(x, y)
            pr_out = pr_h if outcome == "H" else (pr_d if outcome == "D" else pr_a)
            pr_out = float(np.clip(pr_out, eps, 1.0))

            df.at[idx, "pr_home_win"] = pr_h
            df.at[idx, "pr_draw"] = pr_d
            df.at[idx, "pr_away_win"] = pr_a
            df.at[idx, "pr_outcome"] = pr_out
            df.at[idx, "pr_score"] = pr_score
            df.at[idx, "loss_outcome"] = -math.log(pr_out) / math.log(1/3)
            df.at[idx, "loss_score"] = -math.log(pr_score)

            # MAP update -> z mean and full covariance
            post_m, post_cov = self._map_update(prior_m, prior_prec, x, y, neutral)

            # Write back means
            st_h.m = np.array([post_m[0], post_m[1]], dtype=float)
            st_a.m = np.array([post_m[2], post_m[3]], dtype=float)

            # Project posterior covariance blocks back to sigma2 * R
            P_h = post_cov[:2, :2]
            P_a = post_cov[2:, 2:]

            st_h.sigma2 = self._project_sigma2(P_h)
            st_a.sigma2 = self._project_sigma2(P_a)

            # Record parameter history
            cov_ad_h = st_h.sigma2 * self.q0
            cov_ad_a = st_a.sigma2 * self.q0
            params_rows.append({
                "date": t, "team": home,
                "attack_mean": float(st_h.m[0]),
                "defence_mean": float(st_h.m[1]),
                "sigma2": float(st_h.sigma2),
                "cov_ad": float(self.q0 * st_h.sigma2),
            })
            params_rows.append({
                "date": t, "team": away,
                "attack_mean": float(st_a.m[0]),
                "defence_mean": float(st_a.m[1]),
                "sigma2": float(st_a.sigma2),
                "cov_ad": float(self.q0 * st_a.sigma2),
            })

        self.results_ = df
        self.params_history_ = (
            pd.DataFrame(params_rows)
            .sort_values(["date", "team"])
            .reset_index(drop=True)
        )

        self._is_fit = True
        return None

# %%
model = FastDynamicBivarPoissonAD(
    mu=math.log(1.25),          # baseline goals per team
    home_adv=0.12,              # home advantage on log scale
    rho=0.15,                   # correlation strength
    q0=0.3,                     # correlation in attack/defense distribution
    drift_var_per_day=1e-5,     # time-based forgetting
    init_var=0.5,               # uncertainty for new teams
    max_goals=8,                # truncation for W/D/L probs
)
model.fit(results_clean)

# %%
P = model.params_history_.copy()
P["quality_mean"] = P["attack_mean"] + P["defence_mean"]
P.sort_values("quality_mean")
# Out:
#             date            team  attack_mean  defence_mean    sigma2  \
# 88784 2023-11-30  American Samoa    -2.486817     -3.115663  0.030467
# 59596 2007-09-01  American Samoa    -2.435199     -3.094736  0.023009
# 90106 2024-09-06  American Samoa    -2.484014     -3.033055  0.032232
# 59588 2007-08-29  American Samoa    -2.413580     -3.088811  0.023994
# 88770 2023-11-23  American Samoa    -2.470445     -3.020781  0.033946
# ...          ...             ...          ...           ...       ...
# 783   1913-10-05         Denmark     1.407448      0.684257  0.070466
# 2742  1930-03-30      Costa Rica     1.502190      0.799036  0.102624
# 2746  1930-04-04      Costa Rica     1.572617      0.867182  0.087022
# 2730  1930-03-22      Costa Rica     1.693627      0.756388  0.138288
# 2738  1930-03-26      Costa Rica     1.653577      0.885392  0.116516
#
#          cov_ad  quality_mean
# 88784  0.009140     -5.602480
# 59596  0.006903     -5.529935
# 90106  0.009670     -5.517069
# 59588  0.007198     -5.502391
# 88770  0.010184     -5.491226
# ...         ...           ...
# 783    0.021140      2.091705
# 2742   0.030787      2.301226
# 2746   0.026107      2.439799
# 2730   0.041486      2.450014
# 2738   0.034955      2.538969
#
# [92710 rows x 7 columns]

# %%
P.sort_values("sigma2")
# Out:
#             date        team  attack_mean  defence_mean    sigma2    cov_ad  \
# 16202 1971-08-27   Indonesia     0.061341     -0.395258  0.008901  0.002670
# 16544 1971-12-18    Malaysia    -0.187996     -0.454115  0.009037  0.002711
# 16191 1971-08-23   Indonesia     0.083127     -0.374438  0.009058  0.002717
# 16537 1971-12-17    Malaysia    -0.190364     -0.458369  0.009155  0.002747
# 16185 1971-08-21   Indonesia     0.096941     -0.364192  0.009163  0.002749
# ...          ...         ...          ...           ...       ...       ...
# 1     1872-11-30    Scotland    -0.481216      0.137763  0.500000  0.150000
# 12482 1966-04-01   Palestine    -0.890928     -0.003382  0.500000  0.150000
# 71586 2014-03-05      Kosovo    -0.770062     -0.010367  0.500000  0.150000
# 0     1872-11-30     England    -0.137763      0.481216  0.500000  0.150000
# 22682 1979-07-20  Kyrgyzstan    -1.156281      0.197553  0.505043  0.151513
#
#        quality_mean
# 16202     -0.333917
# 16544     -0.642112
# 16191     -0.291311
# 16537     -0.648733
# 16185     -0.267251
# ...             ...
# 1         -0.343453
# 12482     -0.894310
# 71586     -0.780429
# 0          0.343453
# 22682     -0.958728
#
# [92710 rows x 7 columns]

# %%
pd.pivot_table(
    P.loc[P.team.isin(["Australia", "England", "Denmark", "Costa Rica"])],
    index="date",
    columns="team",
    values="sigma2"
).ffill().plot(logy=True)
# hello
# Out:
# <Axes: xlabel='date'>

# %%
get_results("Denmark", model.results_)
# Out:
#             date home_team    away_team  home_score  away_score  \
# 229   1908-10-22    France      Denmark           1          17
# 340   1912-06-30   Denmark       Norway           7           0
# 345   1912-07-02   Denmark  Netherlands           4           1
# 357   1912-10-06   Denmark      Germany           3           1
# 382   1913-05-25   Denmark       Sweden           8           0
# ...          ...       ...          ...         ...         ...
# 45998 2025-09-08    Greece      Denmark           0           3
# 46097 2025-10-09   Belarus      Denmark           0           6
# 46146 2025-10-12   Denmark       Greece           3           1
# 46271 2025-11-15   Denmark      Belarus           2           2
# 46318 2025-11-18  Scotland      Denmark           4           2
#
#                          tournament          city   country  neutral  \
# 229                   Olympic Games        London   England     True
# 340                   Olympic Games     Stockholm    Sweden     True
# 345                   Olympic Games     Stockholm    Sweden     True
# 357                        Friendly    Copenhagen   Denmark    False
# 382                        Friendly    Copenhagen   Denmark    False
# ...                             ...           ...       ...      ...
# 45998  FIFA World Cup qualification        Athens    Greece    False
# 46097  FIFA World Cup qualification  Zalaegerszeg   Hungary     True
# 46146  FIFA World Cup qualification    Copenhagen   Denmark    False
# 46271  FIFA World Cup qualification    Copenhagen   Denmark    False
# 46318  FIFA World Cup qualification       Glasgow  Scotland    False
#
#       shootout_winner shootout_first_shooter  pr_home_win   pr_draw  \
# 229               NaN                    NaN     0.208443  0.249821
# 340               NaN                    NaN     0.999431  0.000468
# 345               NaN                    NaN     0.745685  0.122561
# 357               NaN                    NaN     0.983900  0.011173
# 382               NaN                    NaN     0.953068  0.032253
# ...               ...                    ...          ...       ...
# 45998             NaN                    NaN     0.295979  0.338693
# 46097             NaN                    NaN     0.055258  0.152903
# 46146             NaN                    NaN     0.517940  0.290925
# 46271             NaN                    NaN     0.870796  0.097073
# 46318             NaN                    NaN     0.184864  0.259991
#
#        pr_away_win  pr_outcome      pr_score  loss_outcome  loss_score
# 229       0.541736    0.541736  1.566847e-12     -0.557955   27.181956
# 340       0.000101    0.999431  1.247913e-02     -0.000518    4.383697
# 345       0.131754    0.745685  5.161284e-02     -0.267112    2.963985
# 357       0.004927    0.983900  8.966771e-03     -0.014774    4.714230
# 382       0.014679    0.953068  2.917526e-02     -0.043755    3.534434
# ...            ...         ...           ...           ...         ...
# 45998     0.365328    0.365328  2.018581e-02     -0.916575    3.902775
# 46097     0.791838    0.791838  1.142686e-02     -0.212448    4.471788
# 46146     0.191135    0.517940  4.246757e-02     -0.598843    3.159015
# 46271     0.032131    0.097073  1.543591e-02     -2.122939    4.171058
# 46318     0.555145    0.184864  2.874929e-03     -1.536607    5.851727
#
# [869 rows x 18 columns]

# %%
P.groupby("team").last().quality_mean.sort_values(ascending=False).head(20)
# Out:
# team
# Argentina      1.523718
# Spain          1.405445
# Brazil         1.386969
# England        1.264911
# Colombia       1.187450
# France         1.152529
# Portugal       1.129057
# Netherlands    0.991780
# Germany        0.944041
# Belgium        0.846829
# Japan          0.816353
# Uruguay        0.806927
# Italy          0.733904
# Denmark        0.726553
# Morocco        0.702419
# Ecuador        0.696144
# Croatia        0.694582
# Switzerland    0.685980
# Norway         0.593155
# USA            0.560037
# Name: quality_mean, dtype: float64

# %%
results = pd.read_csv("match_results/results.csv", parse_dates=["date"])
renamer = {
    row.original_name: row.replacement_name
    for row in pd.read_csv("reference_data/kaggle_team_to_canonical_name_map.csv").itertuples()
}
results["home_team"] = results["home_team"].apply(lambda t: renamer.get(t, t))
results["away_team"] = results["away_team"].apply(lambda t: renamer.get(t, t))

# %%
r = results.merge(results_clean, on=["date", "home_team", "away_team"], how="left", suffixes=("", "_right")).query("home_score_right.isna()")

# %%
majors = [
    "FIFA World Cup",
    "Confederations Cup",
    "UEFA Euro",
    "Copa América",
    "African Cup of Nations",
    "AFC Asian Cup",
    "Gold Cup",
    "Oceania Nations Cup",
    "UEFA Nations League",
    "CONCACAF Nations League"
]
majors_plus_qual = [m.lower() for m in majors] + [m.lower() + " qualification" for m in majors]

# %%
worrying = r.loc[r.tournament.str.lower().isin(majors_plus_qual)]

# %%
T = sorted(set(worrying.home_team.to_list() + worrying.away_team.to_list()))
for t in [t for t in T if t not in team_universe]: print(t)
# Out:
# Bonaire
# French Guiana
# Guadeloupe
# Martinique
# Saint Martin
# Sint Maarten

# %%
r.query("~home_score_right.isna()").tournament.value_counts().loc[majors]
# Out:
# tournament
# FIFA World Cup             964
# Confederations Cup         140
# UEFA Euro                  388
# Copa América               869
# African Cup of Nations     793
# AFC Asian Cup              421
# Gold Cup                   373
# Oceania Nations Cup        139
# UEFA Nations League        658
# CONCACAF Nations League    308
# Name: count, dtype: int64

# %%
r.query("home_score_right.isna()").tournament.value_counts().loc[majors]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[211], line 1
# ----> 1 r.query("home_score_right.isna()").tournament.value_counts().loc[majors]
#
# File ~/Desktop/chris gay/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/Desktop/chris gay/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1421, in _LocIndexer._getitem_axis(self, key, axis)
#    1418     if hasattr(key, "ndim") and key.ndim > 1:
#    1419         raise ValueError("Cannot index with multidimensional key")
# -> 1421     return self._getitem_iterable(key, axis=axis)
#    1423 # nested tuple slicing
#    1424 if is_nested_tuple(key, labels):
#
# File ~/Desktop/chris gay/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1361, in _LocIndexer._getitem_iterable(self, key, axis)
#    1358 self._validate_key(key, axis)
#    1360 # A collection of keys
# -> 1361 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1362 return self.obj._reindex_with_indexers(
#    1363     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1364 )
#
# File ~/Desktop/chris gay/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1559, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1556 ax = self.obj._get_axis(axis)
#    1557 axis_name = self.obj._get_axis_name(axis)
# -> 1559 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1561 return keyarr, indexer
#
# File ~/Desktop/chris gay/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~/Desktop/chris gay/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['FIFA World Cup', 'Confederations Cup', 'UEFA Euro', 'Copa América', 'African Cup of Nations', 'AFC Asian Cup', 'Oceania Nations Cup', 'UEFA Nations League'] not in index"

# %%
results_raw = pd.read_csv("match_results/results.csv", parse_dates=["date"])
# former_names = pd.read_csv("match_results/former_names.csv")
results_teams_raw = sorted(set(results_raw.home_team.to_list() + results_raw.away_team.to_list()))
results = results_raw.copy()
mapping = {row.original_name: row.replacement_name for row in pd.read_csv("reference_data/kaggle_team_to_canonical_name_map.csv").itertuples()}
results["home_team"] = results["home_team"].apply(lambda t: mapping.get(t, t))
results["away_team"] = results["away_team"].apply(lambda t: mapping.get(t, t))
results_teams = list(set([mapping.get(name, name) for name in results_teams_raw]))

def get_results(team, results=results):
    return results.query(f"home_team == '{team}' or away_team == '{team}'")

fifa_members_raw = pd.read_csv("reference_data/fifa_members_with_flag_sources.csv").country.to_list()
mapping = {row.original_name: row.replacement_name for row in pd.read_csv("reference_data/fifa_member_to_canonical_name_map.csv").itertuples()}
fifa_members_canonical = [mapping.get(name, name) for name in fifa_members_raw]

results["n_fifa_members"] = results.home_team.isin(fifa_members_canonical).astype(int) + results.away_team.isin(fifa_members_canonical).astype(int)

# %%
teams = pd.DataFrame(
    index=results_teams,
    columns=["both", "one", "neither"],
    dtype=bool
)
teams[:] = False

r = results.loc[results.tournament.str.lower().str.contains("fifa world cup")]#.loc[results.date >= dt.datetime(2000, 1, 1)]
teams.loc[r.query("n_fifa_members == 2").home_team.to_list()+r.query("n_fifa_members == 2").away_team.to_list(), "both"] = True
teams.loc[r.query("n_fifa_members == 1").home_team.to_list()+r.query("n_fifa_members == 1").away_team.to_list(), "one"] = True
teams.loc[r.query("n_fifa_members == 0").home_team.to_list()+r.query("n_fifa_members == 0").away_team.to_list(), "neither"] = True

teams["last_year_played_home"] = r.groupby("home_team").apply(lambda G: G.date.dt.year.max())
teams["last_year_played_away"] = r.groupby("away_team").apply(lambda G: G.date.dt.year.max())
teams["last_year_played_home"] = teams["last_year_played_home"].fillna(0)
teams["last_year_played_away"] = teams["last_year_played_away"].fillna(0)
teams["last_year_played"] = np.maximum(teams["last_year_played_home"], teams["last_year_played_away"]).astype(int)
teams.drop(columns=["last_year_played_home", "last_year_played_away"], inplace=True)

teams["n_matches"] = 0
h = r["home_team"].value_counts()
a = r["away_team"].value_counts()
for x in (h, a):
    teams.loc[x.index, "n_matches"] += x.values
teams["n_matches"] = teams["n_matches"].astype(int)
# Out:
# /var/folders/y9/7mrfwwc97kg93k2qmfccslvm0000gn/T/ipykernel_32100/2797592036.py:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   teams["last_year_played_home"] = r.groupby("home_team").apply(lambda G: G.date.dt.year.max())
# /var/folders/y9/7mrfwwc97kg93k2qmfccslvm0000gn/T/ipykernel_32100/2797592036.py:14: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   teams["last_year_played_away"] = r.groupby("away_team").apply(lambda G: G.date.dt.year.max())

# %%
teams.query("~both").n_matches.sort_values(ascending=False).head(20)
# Out:
# Czechoslovakia               101
# Yugoslavia                    99
# East Germany                  53
# Saarland                       4
# Saint Helena                   0
# Manchukuo                      0
# Madrid                         0
# Saare County                   0
# Republic of St. Pauli          0
# Marshall Islands               0
# United Koreans in Japan        0
# Padania                        0
# Elba Island                    0
# Wallis Islands and Futuna      0
# Délvidék                       0
# Ellan Vannin                   0
# West Papua                     0
# Åland Islands                  0
# County of Nice                 0
# Northern Mariana Islands       0
# Name: n_matches, dtype: int64

# %%
get_results("German DR", r)
# Out:
#             date       home_team       away_team  home_score  away_score  \
# 4457  1957-05-19       German DR           Wales         2.0         1.0
# 4483  1957-06-16  Czechoslovakia       German DR         3.0         1.0
# 4563  1957-09-25           Wales       German DR         4.0         1.0
# 4586  1957-10-27       German DR  Czechoslovakia         1.0         4.0
# 5247  1961-04-16         Hungary       German DR         2.0         0.0
# 5270  1961-05-14       German DR     Netherlands         1.0         1.0
# 5327  1961-09-10       German DR         Hungary         2.0         3.0
# 6270  1965-04-25         Austria       German DR         1.0         1.0
# 6307  1965-05-23       German DR         Hungary         1.0         1.0
# 6463  1965-10-09         Hungary       German DR         3.0         2.0
# 6482  1965-10-31       German DR         Austria         1.0         0.0
# 7630  1969-03-29       German DR           Italy         2.0         2.0
# 7637  1969-04-16       German DR           Wales         2.0         1.0
# 7848  1969-10-22           Wales       German DR         1.0         3.0
# 7912  1969-11-22           Italy       German DR         3.0         0.0
# 9024  1972-10-07       German DR         Finland         5.0         0.0
# 9230  1973-04-08       German DR         Albania         2.0         0.0
# 9321  1973-05-27         Romania       German DR         1.0         0.0
# 9329  1973-06-06         Finland       German DR         1.0         5.0
# 9497  1973-09-26       German DR         Romania         2.0         0.0
# 9559  1973-11-13         Albania       German DR         1.0         4.0
# 9766  1974-06-14       German DR       Australia         2.0         0.0
# 9772  1974-06-18           Chile       German DR         1.0         1.0
# 9782  1974-06-22         Germany       German DR         0.0         1.0
# 9788  1974-06-26          Brazil       German DR         1.0         0.0
# 9794  1974-06-30       German DR     Netherlands         0.0         2.0
# 9797  1974-07-03       Argentina       German DR         1.0         1.0
# 10762 1976-11-17       German DR          Turkey         1.0         1.0
# 10943 1977-04-02           Malta       German DR         0.0         1.0
# 11119 1977-09-24         Austria       German DR         1.0         1.0
# 11150 1977-10-12       German DR         Austria         1.0         1.0
# 11182 1977-10-29       German DR           Malta         9.0         0.0
# 11211 1977-11-16          Turkey       German DR         1.0         2.0
# 12693 1981-04-04           Malta       German DR         1.0         2.0
# 12754 1981-05-02          Poland       German DR         1.0         0.0
# 12981 1981-10-10       German DR          Poland         2.0         3.0
# 13031 1981-11-11       German DR           Malta         5.0         1.0
# 14370 1984-10-20       German DR      Yugoslavia         2.0         3.0
# 14417 1984-11-17      Luxembourg       German DR         0.0         5.0
# 14474 1984-12-08          France       German DR         2.0         0.0
# 14711 1985-04-06        Bulgaria       German DR         1.0         0.0
# 14811 1985-05-18       German DR      Luxembourg         3.0         1.0
# 14964 1985-09-11       German DR          France         2.0         0.0
# 14988 1985-09-28      Yugoslavia       German DR         1.0         2.0
# 15059 1985-11-16       German DR        Bulgaria         2.0         1.0
# 16349 1988-10-19       German DR         Iceland         2.0         0.0
# 16436 1988-11-30          Turkey       German DR         3.0         1.0
# 16637 1989-04-12       German DR          Turkey         0.0         2.0
# 16674 1989-04-26          Russia       German DR         3.0         0.0
# 16708 1989-05-20       German DR         Austria         1.0         1.0
# 16954 1989-09-06         Iceland       German DR         0.0         3.0
# 16983 1989-10-08       German DR          Russia         2.0         1.0
# 17063 1989-11-15         Austria       German DR         3.0         0.0
#
#                          tournament              city         country  \
# 4457   FIFA World Cup qualification           Leipzig       German DR
# 4483   FIFA World Cup qualification              Brno  Czechoslovakia
# 4563   FIFA World Cup qualification           Cardiff           Wales
# 4586   FIFA World Cup qualification           Leipzig       German DR
# 5247   FIFA World Cup qualification          Budapest         Hungary
# 5270   FIFA World Cup qualification           Leipzig       German DR
# 5327   FIFA World Cup qualification            Berlin       German DR
# 6270   FIFA World Cup qualification            Vienna         Austria
# 6307   FIFA World Cup qualification           Leipzig       German DR
# 6463   FIFA World Cup qualification          Budapest         Hungary
# 6482   FIFA World Cup qualification           Leipzig       German DR
# 7630   FIFA World Cup qualification            Berlin       German DR
# 7637   FIFA World Cup qualification           Dresden       German DR
# 7848   FIFA World Cup qualification           Cardiff           Wales
# 7912   FIFA World Cup qualification            Naples           Italy
# 9024   FIFA World Cup qualification           Dresden       German DR
# 9230   FIFA World Cup qualification         Magdeburg       German DR
# 9321   FIFA World Cup qualification         Bucharest         Romania
# 9329   FIFA World Cup qualification           Tampere         Finland
# 9497   FIFA World Cup qualification           Leipzig       German DR
# 9559   FIFA World Cup qualification            Tirana         Albania
# 9766                 FIFA World Cup           Hamburg         Germany
# 9772                 FIFA World Cup            Berlin         Germany
# 9782                 FIFA World Cup           Hamburg         Germany
# 9788                 FIFA World Cup           Hanover         Germany
# 9794                 FIFA World Cup     Gelsenkirchen         Germany
# 9797                 FIFA World Cup     Gelsenkirchen         Germany
# 10762  FIFA World Cup qualification           Dresden       German DR
# 10943  FIFA World Cup qualification             Gżira           Malta
# 11119  FIFA World Cup qualification            Vienna         Austria
# 11150  FIFA World Cup qualification           Leipzig       German DR
# 11182  FIFA World Cup qualification           Potsdam       German DR
# 11211  FIFA World Cup qualification             İzmir          Turkey
# 12693  FIFA World Cup qualification             Gżira           Malta
# 12754  FIFA World Cup qualification           Chorzów          Poland
# 12981  FIFA World Cup qualification           Leipzig       German DR
# 13031  FIFA World Cup qualification              Jena       German DR
# 14370  FIFA World Cup qualification           Leipzig       German DR
# 14417  FIFA World Cup qualification  Esch-sur-Alzette      Luxembourg
# 14474  FIFA World Cup qualification             Paris          France
# 14711  FIFA World Cup qualification             Sofia        Bulgaria
# 14811  FIFA World Cup qualification           Potsdam       German DR
# 14964  FIFA World Cup qualification           Leipzig       German DR
# 14988  FIFA World Cup qualification          Belgrade      Yugoslavia
# 15059  FIFA World Cup qualification   Karl-Marx-Stadt       German DR
# 16349  FIFA World Cup qualification            Berlin       German DR
# 16436  FIFA World Cup qualification          Istanbul          Turkey
# 16637  FIFA World Cup qualification         Magdeburg       German DR
# 16674  FIFA World Cup qualification              Kyiv    Soviet Union
# 16708  FIFA World Cup qualification           Leipzig       German DR
# 16954  FIFA World Cup qualification         Reykjavík         Iceland
# 16983  FIFA World Cup qualification   Karl-Marx-Stadt       German DR
# 17063  FIFA World Cup qualification            Vienna         Austria
#
#        neutral  n_fifa_members
# 4457     False               1
# 4483     False               0
# 4563     False               1
# 4586     False               0
# 5247     False               1
# 5270     False               1
# 5327     False               1
# 6270     False               1
# 6307     False               1
# 6463     False               1
# 6482     False               1
# 7630     False               1
# 7637     False               1
# 7848     False               1
# 7912     False               1
# 9024     False               1
# 9230     False               1
# 9321     False               1
# 9329     False               1
# 9497     False               1
# 9559     False               1
# 9766      True               1
# 9772      True               1
# 9782     False               1
# 9788      True               1
# 9794      True               1
# 9797      True               1
# 10762    False               1
# 10943    False               1
# 11119    False               1
# 11150    False               1
# 11182    False               1
# 11211    False               1
# 12693    False               1
# 12754    False               1
# 12981    False               1
# 13031    False               1
# 14370    False               0
# 14417    False               1
# 14474    False               1
# 14711    False               1
# 14811    False               1
# 14964    False               1
# 14988    False               0
# 15059    False               1
# 16349    False               1
# 16436    False               1
# 16637    False               1
# 16674     True               1
# 16708    False               1
# 16954    False               1
# 16983    False               1
# 17063    False               1

# %%
teams.query("last_year_played > 2000")[["both", "one", "neither"]].value_counts().sort_index()
# Out:
# both   one    neither
# False  False  True        59
#        True   False        4
#               True        44
# True   False  False      101
#        True   False      110
# Name: count, dtype: int64

# %%
r.query("home_team == 'Ynys Môn' or away_team == 'Ynys Môn'")
# Out:
#             date         home_team         away_team  home_score  away_score  \
# 25749 2001-07-08          Ynys Môn      Saare County         4.0         1.0
# 25758 2001-07-10          Ynys Môn          Shetland         1.0         1.0
# 25771 2001-07-12          Ynys Môn            Jersey         2.0         2.0
# 25780 2001-07-13          Guernsey          Ynys Môn         0.0         0.0
# 27325 2003-06-29      Saare County          Ynys Môn         0.0         2.0
# 27345 2003-07-01          Ynys Môn       Isle of Man         1.0         2.0
# 27369 2003-07-04         Gibraltar          Ynys Môn         0.0         2.0
# 29320 2005-07-10         Greenland          Ynys Môn         0.0         0.0
# 29331 2005-07-12            Orkney          Ynys Môn         0.0         2.0
# 29337 2005-07-13          Ynys Môn     Western Isles         0.0         0.0
# 29341 2005-07-14          Guernsey          Ynys Môn         3.0         0.0
# 29345 2005-07-15          Ynys Môn      Saare County         3.0         2.0
# 31015 2007-06-30           Bermuda          Ynys Môn         1.0         2.0
# 31031 2007-07-02          Ynys Môn     Åland Islands         0.0         2.0
# 31039 2007-07-04           Menorca          Ynys Môn         6.0         1.0
# 33095 2009-06-28          Ynys Môn             Frøya         3.0         0.0
# 33102 2009-06-29          Ynys Môn          Guernsey         0.0         2.0
# 33111 2009-06-30         Gibraltar          Ynys Môn         1.0         3.0
# 33126 2009-07-03            Rhodes          Ynys Môn         4.0         0.0
# 34843 2011-06-26     Isle of Wight          Ynys Môn         4.0         0.0
# 34851 2011-06-27         Gibraltar          Ynys Môn         6.0         3.0
# 34857 2011-06-28          Alderney          Ynys Môn         0.0         5.0
# 34873 2011-06-30           Gotland          Ynys Môn         1.0         2.0
# 38847 2015-06-28          Ynys Môn          Guernsey         2.0         5.0
# 38858 2015-06-29         Gibraltar          Ynys Môn         1.0         1.0
# 38864 2015-06-30           Gotland          Ynys Môn         2.0         3.0
# 38875 2015-07-02            Jersey          Ynys Môn         1.0         0.0
# 40740 2017-06-25          Ynys Môn  Falkland Islands         3.0         0.0
# 40750 2017-06-26             Hitra          Ynys Môn         1.0         5.0
# 40759 2017-06-27       Isle of Man          Ynys Môn         4.0         0.0
# 40772 2017-06-29          Ynys Môn     Åland Islands         0.0         2.0
# 42558 2019-06-12          Ynys Môn      Saint Helena         7.0         2.0
# 42573 2019-06-16          Ynys Môn     Western Isles         2.0         1.0
# 42584 2019-06-17          Ynys Môn            Orkney         3.0         1.0
# 42592 2019-06-18          Ynys Môn            Jersey         1.0         0.0
# 42609 2019-06-20          Ynys Môn          Shetland         2.0         1.0
# 42615 2019-06-21          Ynys Môn          Guernsey         2.0         1.0
# 46204 2023-07-09          Ynys Môn          Shetland         2.0         0.0
# 46212 2023-07-10  Falkland Islands          Ynys Môn         1.0         5.0
# 46222 2023-07-11       Isle of Man          Ynys Môn         1.0         2.0
# 46241 2023-07-14          Ynys Môn            Jersey         2.0         5.0
# 48382 2025-07-14          Ynys Môn     Western Isles         1.0         0.0
# 48389 2025-07-17       Isle of Man          Ynys Môn         0.0         1.0
#
#          tournament            city      country  neutral  n_fifa_members
# 25749  Island Games      Castletown  Isle of Man     True               0
# 25758  Island Games         Douglas  Isle of Man     True               0
# 25771  Island Games      Castletown  Isle of Man     True               0
# 25780  Island Games         Douglas  Isle of Man     True               0
# 27325  Island Games   Saint Sampson     Guernsey     True               0
# 27345  Island Games   Saint Sampson     Guernsey     True               0
# 27369  Island Games   Saint Sampson     Guernsey     True               1
# 29320  Island Games        Shetland     Scotland     True               0
# 29331  Island Games        Shetland     Scotland     True               0
# 29337  Island Games        Shetland     Scotland     True               0
# 29341  Island Games        Shetland     Scotland     True               0
# 29345  Island Games        Shetland     Scotland     True               0
# 31015  Island Games          Rhodes       Greece     True               1
# 31031  Island Games          Rhodes       Greece     True               0
# 31039  Island Games          Rhodes       Greece     True               0
# 33095  Island Games          Jomala       Sweden     True               0
# 33102  Island Games          Jomala       Sweden     True               0
# 33111  Island Games      Hammarland       Sweden     True               1
# 33126  Island Games          Eckerö       Sweden     True               0
# 34843  Island Games         Newport      England    False               0
# 34851  Island Games         Brading      England     True               1
# 34857  Island Games        Shanklin      England     True               0
# 34873  Island Games      Freshwater      England     True               0
# 38847  Island Games       St. Peter       Jersey     True               0
# 38858  Island Games       St Helier       Jersey     True               1
# 38864  Island Games       St. Peter       Jersey     True               0
# 38875  Island Games     St. Clement       Jersey    False               0
# 40740  Island Games            Säve       Sweden     True               0
# 40750  Island Games        Väskinde       Sweden     True               0
# 40759  Island Games       Stenkyrka       Sweden     True               0
# 40772  Island Games        Fårösund       Sweden     True               0
# 42558      Friendly        Anglesey        Wales    False               0
# 42573   Inter Games        Anglesey        Wales    False               0
# 42584   Inter Games        Anglesey        Wales    False               0
# 42592   Inter Games        Anglesey        Wales    False               0
# 42609   Inter Games        Anglesey        Wales    False               0
# 42615   Inter Games        Anglesey        Wales    False               0
# 46204  Island Games   Saint Sampson     Guernsey     True               0
# 46212  Island Games   Saint Sampson     Guernsey     True               0
# 46222  Island Games    Saint Martin     Guernsey     True               0
# 46241  Island Games  St. Peter Port     Guernsey     True               0
# 48382  Island Games         Rendall     Scotland     True               0
# 48389  Island Games        Kirkwall     Scotland     True               0

# %%
teams.query("last_year_played > 2000").query("both == False and one == True").sort_values("last_year_played", ascending=False)
# Out:
#                             both   one  neither  last_year_played
# Martinique                 False  True     True              2025
# Guadeloupe                 False  True     True              2025
# Zanzibar                   False  True     True              2025
# Bonaire                    False  True     True              2025
# Ynys Môn                   False  True     True              2025
# Western Isles              False  True     True              2025
# Jersey                     False  True     True              2025
# Sint Maarten               False  True     True              2025
# Shetland                   False  True     True              2025
# Marshall Islands           False  True    False              2025
# Frøya                      False  True     True              2025
# Saint Martin               False  True     True              2025
# Orkney                     False  True     True              2025
# Northern Mariana Islands   False  True     True              2024
# French Guiana              False  True     True              2024
# Réunion                    False  True     True              2023
# Saint Barthélemy           False  True     True              2023
# Tibet                      False  True     True              2023
# Mayotte                    False  True     True              2023
# Tuvalu                     False  True     True              2023
# Menorca                    False  True     True              2023
# Åland Islands              False  True     True              2023
# Isle of Wight              False  True     True              2023
# Guernsey                   False  True     True              2023
# Falkland Islands           False  True     True              2023
# Greenland                  False  True     True              2023
# Alderney                   False  True     True              2022
# Basque Country             False  True     True              2020
# Vatican City               False  True     True              2019
# Catalonia                  False  True     True              2019
# Northern Cyprus            False  True     True              2018
# Monaco                     False  True     True              2017
# Corsica                    False  True     True              2017
# Saare County               False  True     True              2017
# Gotland                    False  True     True              2017
# Galicia                    False  True     True              2016
# Brittany                   False  True     True              2013
# Andalusia                  False  True     True              2013
# Saint Pierre and Miquelon  False  True     True              2012
# Rhodes                     False  True     True              2011
# Kiribati                   False  True     True              2011
# Canary Islands             False  True    False              2007
# Silesia                    False  True    False              2006
# Crimea                     False  True     True              2006
# Republic of St. Pauli      False  True     True              2006
# Găgăuzia                   False  True     True              2006
# Sark                       False  True     True              2003
# Micronesia                 False  True    False              2003

# %%
for t in [t for t in results_teams if t not in fifa_members_canonical]: print(t)
# Out:
# Abkhazia
# Alderney
# Ambazonia
# Andalusia
# Arameans Suryoye
# Artsakh
# Asturias
# Aymara
# Barawa
# Basque Country
# Biafra
# Bonaire
# Brittany
# Canary Islands
# Cascadia
# Catalonia
# Central Spain
# Chagos Islands
# Chameria
# Chechnya
# Cilento
# Corsica
# County of Nice
# Crimea
# Czechoslovakia
# Darfur
# Donetsk PR
# Délvidék
# Elba Island
# Ellan Vannin
# Falkland Islands
# Felvidék
# Franconia
# French Guiana
# Frøya
# Galicia
# German DR
# Gotland
# Gozo
# Greenland
# Guadeloupe
# Guernsey
# Găgăuzia
# Hitra
# Hmong
# Iraqi Kurdistan
# Isle of Man
# Isle of Wight
# Jersey
# Kabylia
# Kernow
# Kiribati
# Kárpátalja
# Luhansk PR
# Madrid
# Manchukuo
# Mapuche
# Marshall Islands
# Martinique
# Matabeleland
# Maule Sur
# Mayotte
# Menorca
# Micronesia
# Monaco
# Niue
# North Vietnam
# Northern Cyprus
# Northern Mariana Islands
# Occitania
# Orkney
# Padania
# Palau
# Panjab
# Parishes of Jersey
# Provence
# Raetia
# Republic of St. Pauli
# Rhodes
# Romani people
# Ryūkyū
# Réunion
# Saare County
# Saarland
# Saint Barthélemy
# Saint Helena
# Saint Martin
# Saint Pierre and Miquelon
# Sark
# Saugeais
# Sealand
# Seborga
# Shetland
# Silesia
# Sint Maarten
# Somaliland
# South Ossetia
# South Yemen
# Surrey
# Székely Land
# Sápmi
# Tamil Eelam
# Tibet
# Ticino
# Tuvalu
# Two Sicilies
# United Koreans in Japan
# Vatican City
# Vietnam Republic
# Wallis Islands and Futuna
# West Papua
# Western Armenia
# Western Australia
# Western Isles
# Western Sahara
# Yemen DPR
# Ynys Môn
# Yorkshire
# Yoruba Nation
# Yugoslavia
# Zanzibar
# Åland Islands

# %%
results
# Out:
#              date              home_team        away_team  home_score  \
# 0      1872-11-30               Scotland          England         0.0
# 1      1873-03-08                England         Scotland         4.0
# 2      1874-03-07               Scotland          England         2.0
# 3      1875-03-06                England         Scotland         2.0
# 4      1876-03-04               Scotland          England         3.0
# ...           ...                    ...              ...         ...
# 48845  2025-11-18  Saint Kitts and Nevis           Belize         2.0
# 48846  2025-11-18    Antigua and Barbuda           Guyana         1.0
# 48847  2025-11-18                   Iran       Uzbekistan         0.0
# 48848  2025-11-19                   Laos          Vietnam         0.0
# 48849  2025-11-20                Vanuatu  Solomon Islands         NaN
#
#        away_score                   tournament          city  \
# 0             0.0                     Friendly       Glasgow
# 1             2.0                     Friendly        London
# 2             1.0                     Friendly       Glasgow
# 3             2.0                     Friendly        London
# 4             0.0                     Friendly       Glasgow
# ...           ...                          ...           ...
# 48845         6.0              CONCACAF Series    Basseterre
# 48846         4.0              CONCACAF Series   North Sound
# 48847         0.0     Al Ain International Cup        Al Ain
# 48848         2.0  AFC Asian Cup qualification     Vientiane
# 48849         NaN     MSG Prime Minister's Cup  Port Moresby
#
#                      country  neutral
# 0                   Scotland    False
# 1                    England    False
# 2                   Scotland    False
# 3                    England    False
# 4                   Scotland    False
# ...                      ...      ...
# 48845  Saint Kitts and Nevis    False
# 48846    Antigua and Barbuda    False
# 48847   United Arab Emirates     True
# 48848                   Laos    False
# 48849       Papua New Guinea     True
#
# [48850 rows x 9 columns]

# %%
L = (results.home_team.to_list() + results.away_team.to_list())
L = sorted(set(L))

# %%
former_name_map = {
    row.former: row.current
    for row in former_names.itertuples()
}

# %%
teams_renamed = [t for t in L if t in former_name_map]
teams_other = [t for t in L if t not in former_name_map]

# %%
teams_other
# Out:
# ['Abkhazia',
#  'Afghanistan',
#  'Albania',
#  'Alderney',
#  'Algeria',
#  'Ambazonia',
#  'American Samoa',
#  'Andalusia',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Arameans Suryoye',
#  'Argentina',
#  'Armenia',
#  'Artsakh',
#  'Aruba',
#  'Asturias',
#  'Australia',
#  'Austria',
#  'Aymara',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barawa',
#  'Barbados',
#  'Basque Country',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Biafra',
#  'Bolivia',
#  'Bonaire',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brittany',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Canary Islands',
#  'Cape Verde',
#  'Cascadia',
#  'Catalonia',
#  'Cayman Islands',
#  'Central African Republic',
#  'Central Spain',
#  'Chad',
#  'Chagos Islands',
#  'Chameria',
#  'Chechnya',
#  'Chile',
#  'China PR',
#  'Cilento',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Cook Islands',
#  'Corsica',
#  'Costa Rica',
#  'County of Nice',
#  'Crimea',
#  'Croatia',
#  'Cuba',
#  'Curaçao',
#  'Cyprus',
#  'Czech Republic',
#  'Czechoslovakia',
#  'DR Congo',
#  'Darfur',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Donetsk PR',
#  'Délvidék',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Elba Island',
#  'Ellan Vannin',
#  'England',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Falkland Islands',
#  'Faroe Islands',
#  'Felvidék',
#  'Fiji',
#  'Finland',
#  'France',
#  'Franconia',
#  'French Guiana',
#  'Frøya',
#  'Gabon',
#  'Galicia',
#  'Gambia',
#  'Georgia',
#  'German DR',
#  'Germany',
#  'Ghana',
#  'Gibraltar',
#  'Gotland',
#  'Gozo',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guadeloupe',
#  'Guam',
#  'Guatemala',
#  'Guernsey',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Găgăuzia',
#  'Haiti',
#  'Hitra',
#  'Hmong',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Iraqi Kurdistan',
#  'Isle of Man',
#  'Isle of Wight',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jersey',
#  'Jordan',
#  'Kabylia',
#  'Kazakhstan',
#  'Kenya',
#  'Kernow',
#  'Kiribati',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Kárpátalja',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Luhansk PR',
#  'Luxembourg',
#  'Macau',
#  'Madagascar',
#  'Madrid',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Manchukuo',
#  'Mapuche',
#  'Marshall Islands',
#  'Martinique',
#  'Matabeleland',
#  'Maule Sur',
#  'Mauritania',
#  'Mauritius',
#  'Mayotte',
#  'Menorca',
#  'Mexico',
#  'Micronesia',
#  'Moldova',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Montserrat',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'New Caledonia',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Niue',
#  'North Korea',
#  'North Macedonia',
#  'North Vietnam',
#  'Northern Cyprus',
#  'Northern Ireland',
#  'Northern Mariana Islands',
#  'Norway',
#  'Occitania',
#  'Oman',
#  'Orkney',
#  'Padania',
#  'Pakistan',
#  'Palau',
#  'Palestine',
#  'Panama',
#  'Panjab',
#  'Papua New Guinea',
#  'Paraguay',
#  'Parishes of Jersey',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Provence',
#  'Puerto Rico',
#  'Qatar',
#  'Raetia',
#  'Republic of Ireland',
#  'Republic of St. Pauli',
#  'Rhodes',
#  'Romani people',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Ryūkyū',
#  'Réunion',
#  'Saare County',
#  'Saarland',
#  'Saint Barthélemy',
#  'Saint Helena',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Martin',
#  'Saint Pierre and Miquelon',
#  'Saint Vincent and the Grenadines',
#  'Samoa',
#  'San Marino',
#  'Sark',
#  'Saudi Arabia',
#  'Saugeais',
#  'Scotland',
#  'Sealand',
#  'Seborga',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Shetland',
#  'Sierra Leone',
#  'Silesia',
#  'Singapore',
#  'Sint Maarten',
#  'Slovakia',
#  'Slovenia',
#  'Solomon Islands',
#  'Somalia',
#  'Somaliland',
#  'South Africa',
#  'South Korea',
#  'South Ossetia',
#  'South Sudan',
#  'South Yemen',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Suriname',
#  'Surrey',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Székely Land',
#  'Sápmi',
#  'São Tomé and Príncipe',
#  'Tahiti',
#  'Taiwan',
#  'Tajikistan',
#  'Tamil Eelam',
#  'Tanzania',
#  'Thailand',
#  'Tibet',
#  'Ticino',
#  'Timor-Leste',
#  'Togo',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'Two Sicilies',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Koreans in Japan',
#  'United States',
#  'United States Virgin Islands',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Vatican City',
#  'Venezuela',
#  'Vietnam',
#  'Vietnam Republic',
#  'Wales',
#  'Wallis Islands and Futuna',
#  'West Papua',
#  'Western Armenia',
#  'Western Australia',
#  'Western Isles',
#  'Western Sahara',
#  'Yemen',
#  'Yemen DPR',
#  'Ynys Môn',
#  'Yorkshire',
#  'Yoruba Nation',
#  'Yugoslavia',
#  'Zambia',
#  'Zanzibar',
#  'Zimbabwe',
#  'Åland Islands']
